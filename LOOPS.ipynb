# %% [markdown]
# Same part of code is executed again and again
#
#
# For loop
#
# While loop

# %%
for i in [2,5,6,2,5]:

  print(i)
# Out:
# 2
# 5
# 6
# 2
# 5

# %%
for i in [2,5,6,2,5]:

  print(i)

  print('hi python')
# Out:
# 2
# hi python
# 5
# hi python
# 6
# hi python
# 2
# hi python
# 5
# hi python

# %%
x=(2,3,4,5,6,7,8,9)

for i in x:

  print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in [2,4,5,1]:


 print('hi python')
 print(i)





print('hi shifa')
# Out:
# hi python
# 2
# hi python
# 4
# hi python
# 5
# hi python
# 1
# hi shifa
